# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests


# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=05026d7c5465299b74bb60225b6ac121

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 'qaanaaq'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mandera
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | havelock
# Processing Record 5 of Set 1 | meulaboh
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 1 | manokwari
# Processing Record 12 of Set 1 | konstantynow lodzki
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | pinsk
# Processing Record 15 of Set 1 | linqiong
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | nemyriv
# Processing Record 20 of Set 1 | olafsvik
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | adrar
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | amapa
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | kiunga
# Processing Record 32 of Set 1 | batesville
# Processing Record 33 of Set 1 | aberystwyth
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | mokrousovo
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | tynda
# Processing Record 39 of Set 1 | laredo
# Processing Record 40 of Set 1 | anadyr
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | tautira
# Processing Record 44 of Set 1 | buala
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | guntakal
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | tiznit
# Processing Record 1 of Set 2 | el astillero
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | ugoofaaru
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | harnosand
# Processing Record 6 of Set 2 | bonanza
# Processing Record 7 of Set 2 | kattivakkam
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | rincon
# Processing Record 10 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 2 | cravo norte
# Processing Record 12 of Set 2 | nouadhibou
# Processing Record 13 of Set 2 | biltine
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | novaya igirma
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | knysna
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | sri aman
# Processing Record 23 of Set 2 | bayji
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | tejupilco
# City not found. Skipping...
# Processing Record 26 of Set 2 | indiaroba
# Processing Record 27 of Set 2 | santa luzia
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | havre-saint-pierre
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | lata
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | komsomolskiy
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | denpasar
# Processing Record 38 of Set 2 | lorengau
# Processing Record 39 of Set 2 | zapolyarnyy
# Processing Record 40 of Set 2 | bahir dar
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | port arthur
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | meaford
# Processing Record 46 of Set 2 | yar-sale
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | kalianget
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | port hardy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\DCANOW~1\AppData\Local\Temp/ipykernel_22988/2903118662.py in <module>
#      15         set_count += 1
#      16         record_count = 1
# ---> 17         time.sleep(60)
#      18
#      19     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bluff -46.6000  168.3333     48.87        74          63
# 1        Qaanaaq  77.4840  -69.3632     -2.52        73          12
# 2          Kapaa  22.0752 -159.3190     71.58        94           1
# 3          Kathu   7.9178   98.3332     81.70        99         100
# 4         Bethel  41.3712  -73.4140     51.93        56          20
# 5         Avarua -21.2078 -159.7750     77.05        94          75
# 6        Rikitea -23.1203 -134.9692     73.17        69          34
# 7    New Norfolk -42.7826  147.0587     49.50        75          98
# 8      Tuatapere -46.1333  167.6833     41.50        86          61
# 9  Leningradskiy  69.3833  178.4167     -3.66        91           8
#
#    Wind Speed Country                 Date
# 0       12.93      NZ  2021-11-17 16:26:27
# 1        5.53      GL  2021-11-17 16:26:27
# 2        8.05      US  2021-11-17 16:26:27
# 3        7.56      TH  2021-11-17 16:26:28
# 4        1.01      US  2021-11-17 16:26:28
# 5        9.22      CK  2021-11-17 16:26:28
# 6       17.83      PF  2021-11-17 16:22:13
# 7        3.09      AU  2021-11-17 16:26:28
# 8        5.21      NZ  2021-11-17 16:26:29
# 9        9.35      RU  2021-11-17 16:26:29

# %%
#reorder the columns
new_column_order_df = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"] 
df_new_order = city_data_df[new_column_order_df]
df_new_order
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0          Bluff      NZ  2021-11-17 16:26:27 -46.6000  168.3333     48.87
# 1        Qaanaaq      GL  2021-11-17 16:26:27  77.4840  -69.3632     -2.52
# 2          Kapaa      US  2021-11-17 16:26:27  22.0752 -159.3190     71.58
# 3          Kathu      TH  2021-11-17 16:26:28   7.9178   98.3332     81.70
# 4         Bethel      US  2021-11-17 16:26:28  41.3712  -73.4140     51.93
# ..           ...     ...                  ...      ...       ...       ...
# 563         Mayo      US  2021-11-17 16:37:39  38.8876  -76.5119     61.34
# 564  Kloulklubed      PW  2021-11-17 16:41:19   7.0419  134.2556     77.50
# 565      Huilong      CN  2021-11-17 16:38:36  31.8111  121.6550     59.04
# 566      Burbach      DE  2021-11-17 16:41:20  50.7500    8.0833     43.43
# 567      Batagay      RU  2021-11-17 16:38:54  67.6333  134.6333    -14.35
#
#      Humidity  Cloudiness  Wind Speed
# 0          74          63       12.93
# 1          73          12        5.53
# 2          94           1        8.05
# 3          99         100        7.56
# 4          56          20        1.01
# ..        ...         ...         ...
# 563        67          90        5.01
# 564        79          89        4.85
# 565        77         100        4.94
# 566        96          90        6.91
# 567        99         100        0.92
#
# [568 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '11/17/21'

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
    
    print(f"R-squared: {r_value**2}")

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DCANOW~1\AppData\Local\Temp/ipykernel_20768/1036248773.py in <module>
# ----> 1 index13 = city_data_df.loc[13]
#       2 index13
#
# NameError: name 'city_data_df' is not defined

# %%
city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,80))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DCANOW~1\AppData\Local\Temp/ipykernel_20768/976616432.py in <module>
#       1 # Linear regression on the Southern Hemisphere
# ----> 2 x_values = southern_hemi_df["Lat"]
#       3 y_values = southern_hemi_df["Wind Speed"]
#       4 # Call the function.
#       5 plot_linear_regression(x_values, y_values,
#
# NameError: name 'southern_hemi_df' is not defined
