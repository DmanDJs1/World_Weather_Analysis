# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests


# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=05026d7c5465299b74bb60225b6ac121

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | puerto escondido
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | dingtao
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | pacific grove
# Processing Record 14 of Set 1 | portland
# Processing Record 15 of Set 1 | saint anthony
# Processing Record 16 of Set 1 | erenhot
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | hadejia
# Processing Record 19 of Set 1 | hambantota
# Processing Record 20 of Set 1 | kolno
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | beira
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | sioux lookout
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | canton
# Processing Record 31 of Set 1 | chany
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | terney
# Processing Record 36 of Set 1 | heishan
# Processing Record 37 of Set 1 | caucaia
# Processing Record 38 of Set 1 | kupang
# Processing Record 39 of Set 1 | sanchor
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | ternate
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | bara
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | bestobe
# Processing Record 5 of Set 2 | korem
# Processing Record 6 of Set 2 | bikaner
# Processing Record 7 of Set 2 | brae
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | kloulklubed
# Processing Record 10 of Set 2 | play cu
# City not found. Skipping...
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | kirakira
# Processing Record 15 of Set 2 | arroyo
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | airai
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | paratinga
# Processing Record 21 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto madryn
# Processing Record 23 of Set 2 | panguna
# Processing Record 24 of Set 2 | tiarei
# Processing Record 25 of Set 2 | narsaq
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | botesti
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 2 | sinop
# Processing Record 32 of Set 2 | ekhabi
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | ust-maya
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | lapua
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | katobu
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | arlit
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | mahajanga
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | znamenskoye
# Processing Record 47 of Set 2 | hofn
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | olafsvik
# Processing Record 50 of Set 2 | manta
# Processing Record 1 of Set 3 | lata
# Processing Record 2 of Set 3 | praia da vitoria
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | rehli
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | yarmouth
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | krasnyy chikoy
# Processing Record 9 of Set 3 | bandundu
# Processing Record 10 of Set 3 | hibbing
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | dale
# Processing Record 13 of Set 3 | naze
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | san cristobal
# Processing Record 19 of Set 3 | bereda
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | katiola
# Processing Record 22 of Set 3 | okha
# Processing Record 23 of Set 3 | kyabram
# Processing Record 24 of Set 3 | kalabo
# Processing Record 25 of Set 3 | hami
# Processing Record 26 of Set 3 | lazaro cardenas
# Processing Record 27 of Set 3 | chokurdakh
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | sept-iles
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | ust-kuyga
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | nizhniy kuranakh
# Processing Record 35 of Set 3 | bubaque
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | zarubino
# Processing Record 38 of Set 3 | rivne
# Processing Record 39 of Set 3 | meadow lake
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | krasnoselkup
# Processing Record 44 of Set 3 | helong
# Processing Record 45 of Set 3 | bratsk
# Processing Record 46 of Set 3 | westport
# Processing Record 47 of Set 3 | bilma
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | moron
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | sharjah
# Processing Record 3 of Set 4 | mandalgovi
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | dwarka
# Processing Record 6 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | butaritari
# Processing Record 8 of Set 4 | kahului
# Processing Record 9 of Set 4 | leningradskiy
# Processing Record 10 of Set 4 | moussoro
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | beringovskiy
# Processing Record 13 of Set 4 | port lavaca
# Processing Record 14 of Set 4 | rockhampton
# Processing Record 15 of Set 4 | aswan
# Processing Record 16 of Set 4 | maceio
# Processing Record 17 of Set 4 | itarema
# Processing Record 18 of Set 4 | cascas
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | vicksburg
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | vostok
# Processing Record 24 of Set 4 | ibipeba
# Processing Record 25 of Set 4 | faya
# Processing Record 26 of Set 4 | mbekenyera
# Processing Record 27 of Set 4 | fiditi
# Processing Record 28 of Set 4 | puerto ayacucho
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | san andres
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | prince rupert
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | dhidhdhoo
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 4 | rovira
# Processing Record 40 of Set 4 | ngunguru
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | turbat
# Processing Record 43 of Set 4 | san lawrenz
# Processing Record 44 of Set 4 | bayevo
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | bilibino
# Processing Record 48 of Set 4 | fairbanks
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | nome
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | camalu
# Processing Record 4 of Set 5 | dudinka
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | jiazi
# Processing Record 8 of Set 5 | smidovich
# Processing Record 9 of Set 5 | waipawa
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | juneau
# Processing Record 12 of Set 5 | collie
# Processing Record 13 of Set 5 | port antonio
# Processing Record 14 of Set 5 | tezu
# Processing Record 15 of Set 5 | presidencia roque saenz pena
# Processing Record 16 of Set 5 | huicungo
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | ust-ishim
# Processing Record 19 of Set 5 | acari
# Processing Record 20 of Set 5 | broken hill
# Processing Record 21 of Set 5 | ilva mica
# Processing Record 22 of Set 5 | beian
# Processing Record 23 of Set 5 | kieta
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | sarti
# Processing Record 26 of Set 5 | wewak
# Processing Record 27 of Set 5 | gotsu
# Processing Record 28 of Set 5 | axim
# Processing Record 29 of Set 5 | xai-xai
# Processing Record 30 of Set 5 | koppang
# Processing Record 31 of Set 5 | nantucket
# Processing Record 32 of Set 5 | taoudenni
# Processing Record 33 of Set 5 | idlib
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | camacha
# Processing Record 37 of Set 5 | hilo
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | turukhansk
# Processing Record 40 of Set 5 | dalbandin
# Processing Record 41 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 5 | boa vista
# Processing Record 43 of Set 5 | butajira
# Processing Record 44 of Set 5 | bathsheba
# Processing Record 45 of Set 5 | spokane
# Processing Record 46 of Set 5 | florina
# Processing Record 47 of Set 5 | autlan
# City not found. Skipping...
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | ostersund
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | olinda
# Processing Record 2 of Set 6 | ilulissat
# Processing Record 3 of Set 6 | grand gaube
# Processing Record 4 of Set 6 | srivardhan
# Processing Record 5 of Set 6 | tigil
# Processing Record 6 of Set 6 | udachnyy
# Processing Record 7 of Set 6 | wisconsin rapids
# Processing Record 8 of Set 6 | kavaratti
# Processing Record 9 of Set 6 | lavrentiya
# Processing Record 10 of Set 6 | yerbogachen
# Processing Record 11 of Set 6 | saint-joseph
# Processing Record 12 of Set 6 | camp verde
# Processing Record 13 of Set 6 | tripoli
# Processing Record 14 of Set 6 | salta
# Processing Record 15 of Set 6 | karasburg
# Processing Record 16 of Set 6 | tahta
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | iquique
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | maniitsoq
# Processing Record 21 of Set 6 | margherita
# Processing Record 22 of Set 6 | lithgow
# Processing Record 23 of Set 6 | merauke
# Processing Record 24 of Set 6 | sarkand
# Processing Record 25 of Set 6 | roches noires
# City not found. Skipping...
# Processing Record 26 of Set 6 | richards bay
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | port macquarie
# Processing Record 29 of Set 6 | mao
# Processing Record 30 of Set 6 | norman wells
# Processing Record 31 of Set 6 | roma
# Processing Record 32 of Set 6 | sobolevo
# Processing Record 33 of Set 6 | chagoda
# Processing Record 34 of Set 6 | half moon bay
# Processing Record 35 of Set 6 | srednekolymsk
# Processing Record 36 of Set 6 | marsa matruh
# Processing Record 37 of Set 6 | huron
# Processing Record 38 of Set 6 | dolores
# Processing Record 39 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 6 | mastic beach
# Processing Record 41 of Set 6 | saint-augustin
# Processing Record 42 of Set 6 | rio grande
# Processing Record 43 of Set 6 | biu
# Processing Record 44 of Set 6 | eureka
# Processing Record 45 of Set 6 | cherusti
# Processing Record 46 of Set 6 | tabou
# Processing Record 47 of Set 6 | indramayu
# Processing Record 48 of Set 6 | van
# Processing Record 49 of Set 6 | waddan
# Processing Record 50 of Set 6 | fort nelson
# Processing Record 1 of Set 7 | araceli
# Processing Record 2 of Set 7 | nioro
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | vallenar
# Processing Record 5 of Set 7 | pak phanang
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | stoneham
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | kutum
# Processing Record 10 of Set 7 | sechura
# Processing Record 11 of Set 7 | tarrafal
# Processing Record 12 of Set 7 | edson
# Processing Record 13 of Set 7 | chapais
# Processing Record 14 of Set 7 | vilhena
# Processing Record 15 of Set 7 | kamina
# Processing Record 16 of Set 7 | lahaina
# Processing Record 17 of Set 7 | grindavik
# Processing Record 18 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 7 | novaya igirma
# Processing Record 20 of Set 7 | chake chake
# Processing Record 21 of Set 7 | madang
# Processing Record 22 of Set 7 | reutte
# Processing Record 23 of Set 7 | aberdeen
# Processing Record 24 of Set 7 | paraiso
# Processing Record 25 of Set 7 | buin
# Processing Record 26 of Set 7 | acapulco
# Processing Record 27 of Set 7 | labuhan
# Processing Record 28 of Set 7 | racine
# Processing Record 29 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 30 of Set 7 | elko
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | porto nacional
# Processing Record 33 of Set 7 | xuddur
# Processing Record 34 of Set 7 | north bend
# Processing Record 35 of Set 7 | churapcha
# Processing Record 36 of Set 7 | vila velha
# Processing Record 37 of Set 7 | antsohihy
# Processing Record 38 of Set 7 | capaci
# Processing Record 39 of Set 7 | hualmay
# Processing Record 40 of Set 7 | necochea
# Processing Record 41 of Set 7 | whitehorse
# Processing Record 42 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 7 | la orilla
# Processing Record 44 of Set 7 | uyemskiy
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | puerto colombia
# Processing Record 48 of Set 7 | kidal
# Processing Record 49 of Set 7 | san jeronimo
# Processing Record 50 of Set 7 | iqaluit
# Processing Record 1 of Set 8 | mackay
# Processing Record 2 of Set 8 | havre-saint-pierre
# Processing Record 3 of Set 8 | gorontalo
# Processing Record 4 of Set 8 | harrison
# Processing Record 5 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 8 | nyurba
# Processing Record 7 of Set 8 | mehamn
# Processing Record 8 of Set 8 | helena
# Processing Record 9 of Set 8 | buluang
# Processing Record 10 of Set 8 | roebourne
# Processing Record 11 of Set 8 | tarakan
# Processing Record 12 of Set 8 | nuuk
# Processing Record 13 of Set 8 | lagoa
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | tura
# Processing Record 16 of Set 8 | ko samui
# Processing Record 17 of Set 8 | santa maria da vitoria
# Processing Record 18 of Set 8 | garden city
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | shingu
# Processing Record 21 of Set 8 | namatanai
# Processing Record 22 of Set 8 | balsas
# Processing Record 23 of Set 8 | makokou
# Processing Record 24 of Set 8 | vitry-le-francois
# Processing Record 25 of Set 8 | rio cuarto
# Processing Record 26 of Set 8 | mokhsogollokh
# Processing Record 27 of Set 8 | songjianghe
# Processing Record 28 of Set 8 | mount isa
# Processing Record 29 of Set 8 | moanda
# Processing Record 30 of Set 8 | luang prabang
# Processing Record 31 of Set 8 | miri
# Processing Record 32 of Set 8 | port blair
# Processing Record 33 of Set 8 | kapit
# Processing Record 34 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 8 | acarau
# Processing Record 36 of Set 8 | teknaf
# Processing Record 37 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 8 | trincomalee
# Processing Record 39 of Set 8 | mahibadhoo
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | sambava
# Processing Record 42 of Set 8 | christchurch
# Processing Record 43 of Set 8 | nakamura
# Processing Record 44 of Set 8 | dawei
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | zeya
# Processing Record 47 of Set 8 | walla walla
# Processing Record 48 of Set 8 | husavik
# Processing Record 49 of Set 8 | yumen
# Processing Record 50 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 9 | sao sebastiao
# Processing Record 2 of Set 9 | bukoba
# Processing Record 3 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 4 of Set 9 | anadyr
# Processing Record 5 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 9 | yazd
# Processing Record 7 of Set 9 | salalah
# Processing Record 8 of Set 9 | kokopo
# Processing Record 9 of Set 9 | inhambane
# Processing Record 10 of Set 9 | iquitos
# Processing Record 11 of Set 9 | solnechnyy
# Processing Record 12 of Set 9 | ancud
# Processing Record 13 of Set 9 | tekirdag
# Processing Record 14 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 15 of Set 9 | rapid valley
# Processing Record 16 of Set 9 | timizart
# Processing Record 17 of Set 9 | moose factory
# Processing Record 18 of Set 9 | tocopilla
# Processing Record 19 of Set 9 | santa rosa
# Processing Record 20 of Set 9 | inuvik
# Processing Record 21 of Set 9 | khorixas
# Processing Record 22 of Set 9 | kembe
# Processing Record 23 of Set 9 | tias
# Processing Record 24 of Set 9 | fare
# Processing Record 25 of Set 9 | bajil
# Processing Record 26 of Set 9 | kodinsk
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | hinton
# Processing Record 29 of Set 9 | alugan
# Processing Record 30 of Set 9 | ust-tsilma
# Processing Record 31 of Set 9 | saint george
# Processing Record 32 of Set 9 | doctor juan leon mallorquin
# Processing Record 33 of Set 9 | shimoda
# Processing Record 34 of Set 9 | shahr-e babak
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | sanming
# Processing Record 37 of Set 9 | qiongshan
# Processing Record 38 of Set 9 | khabary
# Processing Record 39 of Set 9 | abu samrah
# Processing Record 40 of Set 9 | geraldton
# Processing Record 41 of Set 9 | kintampo
# Processing Record 42 of Set 9 | biak
# Processing Record 43 of Set 9 | boguchany
# Processing Record 44 of Set 9 | el alto
# Processing Record 45 of Set 9 | esperance
# Processing Record 46 of Set 9 | san jose
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | motygino
# Processing Record 49 of Set 9 | cherskiy
# Processing Record 50 of Set 9 | buraydah
# Processing Record 1 of Set 10 | santiago del estero
# Processing Record 2 of Set 10 | general roca
# Processing Record 3 of Set 10 | skibbereen
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | russell
# Processing Record 6 of Set 10 | kaihua
# Processing Record 7 of Set 10 | havoysund
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | domodossola
# Processing Record 11 of Set 10 | itaituba
# Processing Record 12 of Set 10 | tutoia
# Processing Record 13 of Set 10 | hasaki
# Processing Record 14 of Set 10 | zhigansk
# Processing Record 15 of Set 10 | alta floresta
# Processing Record 16 of Set 10 | payo
# Processing Record 17 of Set 10 | bodaybo
# Processing Record 18 of Set 10 | san patricio
# Processing Record 19 of Set 10 | nouadhibou
# Processing Record 20 of Set 10 | panguipulli
# Processing Record 21 of Set 10 | sitka
# Processing Record 22 of Set 10 | tumpat
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 10 | vredendal
# Processing Record 26 of Set 10 | talcher
# Processing Record 27 of Set 10 | atikokan
# Processing Record 28 of Set 10 | penzance
# Processing Record 29 of Set 10 | carballo
# Processing Record 30 of Set 10 | cortland
# Processing Record 31 of Set 10 | dogondoutchi
# Processing Record 32 of Set 10 | pangnirtung
# Processing Record 33 of Set 10 | banamba
# Processing Record 34 of Set 10 | rumoi
# Processing Record 35 of Set 10 | nikolsk
# Processing Record 36 of Set 10 | edgewater
# Processing Record 37 of Set 10 | thabazimbi
# Processing Record 38 of Set 10 | tiruvannamalai
# Processing Record 39 of Set 10 | thanatpin
# Processing Record 40 of Set 10 | at-bashi
# Processing Record 41 of Set 10 | bajina basta
# Processing Record 42 of Set 10 | ahipara
# Processing Record 43 of Set 10 | horasan
# Processing Record 44 of Set 10 | aksarka
# Processing Record 45 of Set 10 | hervey bay
# Processing Record 46 of Set 10 | peterhead
# Processing Record 47 of Set 10 | pietarsaari
# Processing Record 48 of Set 10 | eydhafushi
# Processing Record 49 of Set 10 | abrego
# Processing Record 50 of Set 10 | pachino
# Processing Record 1 of Set 11 | porosozero
# Processing Record 2 of Set 11 | egvekinot
# Processing Record 3 of Set 11 | navalmoral de la mata
# Processing Record 4 of Set 11 | cerkezkoy
# Processing Record 5 of Set 11 | pochutla
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | yaroslavskiy
# Processing Record 8 of Set 11 | bintulu
# Processing Record 9 of Set 11 | cockburn town
# Processing Record 10 of Set 11 | galesong
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | ninghai
# Processing Record 13 of Set 11 | takoradi
# Processing Record 14 of Set 11 | alcaniz
# Processing Record 15 of Set 11 | gao
# Processing Record 16 of Set 11 | wuchang
# Processing Record 17 of Set 11 | sao miguel do guama
# Processing Record 18 of Set 11 | ikalamavony
# Processing Record 19 of Set 11 | petushki
# Processing Record 20 of Set 11 | morgantown
# Processing Record 21 of Set 11 | mercedes
# Processing Record 22 of Set 11 | baykit
# Processing Record 23 of Set 11 | talnakh
# Processing Record 24 of Set 11 | blackwater
# Processing Record 25 of Set 11 | lieksa
# Processing Record 26 of Set 11 | mana
# Processing Record 27 of Set 11 | teguldet
# Processing Record 28 of Set 11 | sujiatun
# Processing Record 29 of Set 11 | jumla
# Processing Record 30 of Set 11 | tecoanapa
# Processing Record 31 of Set 11 | morristown
# Processing Record 32 of Set 11 | denpasar
# Processing Record 33 of Set 11 | marrakesh
# Processing Record 34 of Set 11 | killybegs
# Processing Record 35 of Set 11 | petukhovo
# Processing Record 36 of Set 11 | telimele
# Processing Record 37 of Set 11 | siyabuswa
# Processing Record 38 of Set 11 | roald
# Processing Record 39 of Set 11 | grootfontein
# Processing Record 40 of Set 11 | kindu
# Processing Record 41 of Set 11 | arman
# Processing Record 42 of Set 11 | muskegon
# Processing Record 43 of Set 11 | ossora
# Processing Record 44 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 11 | veydelevka
# Processing Record 46 of Set 11 | umarkhed
# Processing Record 47 of Set 11 | ati
# Processing Record 48 of Set 11 | poum
# Processing Record 49 of Set 11 | novyy urengoy
# Processing Record 50 of Set 11 | sungurlu
# Processing Record 1 of Set 12 | salinas
# Processing Record 2 of Set 12 | tual
# Processing Record 3 of Set 12 | oranjemund
# Processing Record 4 of Set 12 | rawson
# Processing Record 5 of Set 12 | akyab
# Processing Record 6 of Set 12 | ulaangom
# Processing Record 7 of Set 12 | upata
# Processing Record 8 of Set 12 | ostrovnoy
# Processing Record 9 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 12 | derzhavinsk
# Processing Record 11 of Set 12 | bridlington
# Processing Record 12 of Set 12 | hvolsvollur
# Processing Record 13 of Set 12 | bardiyah
# Processing Record 14 of Set 12 | pangkalanbuun
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | pangoa
# Processing Record 17 of Set 12 | paterson
# Processing Record 18 of Set 12 | kuybyshevo
# Processing Record 19 of Set 12 | constantine
# Processing Record 20 of Set 12 | bhainsdehi
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | antofagasta
# Processing Record 23 of Set 12 | meridian
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | dukat
# Processing Record 26 of Set 12 | tabuk
# Processing Record 27 of Set 12 | krasnogorskoye
# Processing Record 28 of Set 12 | mindelo
# Processing Record 29 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 12 | coahuayana
# Processing Record 31 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 12 | pinega
# Processing Record 33 of Set 12 | kothapet
# Processing Record 34 of Set 12 | altamont
# Processing Record 35 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 12 | whangarei
# Processing Record 38 of Set 12 | hattiesburg
# Processing Record 39 of Set 12 | gainesville
# Processing Record 40 of Set 12 | gangapur
# Processing Record 41 of Set 12 | nanortalik
# Processing Record 42 of Set 12 | leeton
# Processing Record 43 of Set 12 | padang
# Processing Record 44 of Set 12 | dzerzhinskoye
# Processing Record 45 of Set 12 | khingansk
# Processing Record 46 of Set 12 | perpignan
# Processing Record 47 of Set 12 | mogadishu
# Processing Record 48 of Set 12 | apatzingan
# Processing Record 49 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 12 | gari
# Processing Record 1 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 13 | sao joao da barra
# Processing Record 3 of Set 13 | chingirlau
# Processing Record 4 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 13 | karnobat
# Processing Record 6 of Set 13 | mayor pablo lagerenza
# Processing Record 7 of Set 13 | severo-kurilsk
# Processing Record 8 of Set 13 | jackson
# Processing Record 9 of Set 13 | panji
# Processing Record 10 of Set 13 | sri aman
# Processing Record 11 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 13 | susanville
# Processing Record 13 of Set 13 | plouzane
# Processing Record 14 of Set 13 | auki
# Processing Record 15 of Set 13 | vestmannaeyjar
# Processing Record 16 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 13 | saint-michel-des-saints
# Processing Record 18 of Set 13 | borodino
# Processing Record 19 of Set 13 | puerto del rosario
# Processing Record 20 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 13 | nanhyanga
# Processing Record 22 of Set 13 | alice springs
# Processing Record 23 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 24 of Set 13 | los zacatones
# Processing Record 25 of Set 13 | matay
# Processing Record 26 of Set 13 | proletariy
# Processing Record 27 of Set 13 | skovorodino
# Processing Record 28 of Set 13 | xining
# Processing Record 29 of Set 13 | karmana
# City not found. Skipping...
# Processing Record 30 of Set 13 | marzuq
# Processing Record 31 of Set 13 | siderno
# Processing Record 32 of Set 13 | foix
# Processing Record 33 of Set 13 | coihaique
# Processing Record 34 of Set 13 | agde
# Processing Record 35 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 13 | charters towers
# Processing Record 38 of Set 13 | chernyshevskiy
# Processing Record 39 of Set 13 | kawalu
# Processing Record 40 of Set 13 | sayat
# Processing Record 41 of Set 13 | george
# Processing Record 42 of Set 13 | along
# Processing Record 43 of Set 13 | fuyu
# Processing Record 44 of Set 13 | srandakan
# Processing Record 45 of Set 13 | mildura
# Processing Record 46 of Set 13 | krasnyy luch
# Processing Record 47 of Set 13 | cayenne
# Processing Record 48 of Set 13 | hirson
# Processing Record 49 of Set 13 | brumado
# Processing Record 50 of Set 13 | goderich
# Processing Record 1 of Set 14 | port hueneme
# Processing Record 2 of Set 14 | pokhara
# Processing Record 3 of Set 14 | adrar
# Processing Record 4 of Set 14 | khudumelapye
# Processing Record 5 of Set 14 | bose
# Processing Record 6 of Set 14 | asfi
# Processing Record 7 of Set 14 | deyang
# Processing Record 8 of Set 14 | pundaguitan
# Processing Record 9 of Set 14 | santa marta
# Processing Record 10 of Set 14 | saint-georges
# Processing Record 11 of Set 14 | kotido
# Processing Record 12 of Set 14 | vila do maio
# Processing Record 13 of Set 14 | aguimes
# Processing Record 14 of Set 14 | hirara
# Processing Record 15 of Set 14 | senanga
# Processing Record 16 of Set 14 | caceres
# Processing Record 17 of Set 14 | gamboula
# Processing Record 18 of Set 14 | oktyabrskiy
# Processing Record 19 of Set 14 | okhotsk
# Processing Record 20 of Set 14 | abha
# Processing Record 21 of Set 14 | neuquen
# Processing Record 22 of Set 14 | yebaishou
# Processing Record 23 of Set 14 | keetmanshoop
# Processing Record 24 of Set 14 | surskoye
# Processing Record 25 of Set 14 | santana do livramento
# Processing Record 26 of Set 14 | kysyl-syr
# Processing Record 27 of Set 14 | tsabong
# Processing Record 28 of Set 14 | watertown
# Processing Record 29 of Set 14 | le vauclin
# Processing Record 30 of Set 14 | ust-nera
# Processing Record 31 of Set 14 | sao felix do xingu
# Processing Record 32 of Set 14 | khonsa
# Processing Record 33 of Set 14 | petauke
# Processing Record 34 of Set 14 | halifax
# Processing Record 35 of Set 14 | rorvik
# Processing Record 36 of Set 14 | quatre cocos
# Processing Record 37 of Set 14 | tromso
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | fort morgan
# Processing Record 40 of Set 14 | poshekhonye
# Processing Record 41 of Set 14 | saint-pascal
# City not found. Skipping...
# Processing Record 42 of Set 14 | santa cruz de la palma
# Processing Record 43 of Set 14 | mumford
# Processing Record 44 of Set 14 | kijang
# Processing Record 45 of Set 14 | balkanabat
# Processing Record 46 of Set 14 | avera
# Processing Record 47 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 48 of Set 14 | acajutla
# Processing Record 49 of Set 14 | simao
# Processing Record 50 of Set 14 | verkhnetulomskiy
# Processing Record 1 of Set 15 | kenai
# Processing Record 2 of Set 15 | taksimo
# Processing Record 3 of Set 15 | casa grande
# Processing Record 4 of Set 15 | fukue
# Processing Record 5 of Set 15 | coffs harbour
# Processing Record 6 of Set 15 | omboue
# Processing Record 7 of Set 15 | chongwe
# Processing Record 8 of Set 15 | taman
# Processing Record 9 of Set 15 | marsh harbour
# Processing Record 10 of Set 15 | kirkwall
# Processing Record 11 of Set 15 | mangrol
# Processing Record 12 of Set 15 | eunice
# Processing Record 13 of Set 15 | guerrero negro
# Processing Record 14 of Set 15 | teya
# Processing Record 15 of Set 15 | kirando
# Processing Record 16 of Set 15 | talaya
# Processing Record 17 of Set 15 | harper
# Processing Record 18 of Set 15 | broome
# Processing Record 19 of Set 15 | fortuna
# Processing Record 20 of Set 15 | oil city
# Processing Record 21 of Set 15 | corn island
# Processing Record 22 of Set 15 | itamarandiba
# Processing Record 23 of Set 15 | tucuman
# Processing Record 24 of Set 15 | preobrazheniye
# Processing Record 25 of Set 15 | valparaiso
# Processing Record 26 of Set 15 | klyuchi
# Processing Record 27 of Set 15 | suhut
# Processing Record 28 of Set 15 | manggar
# Processing Record 29 of Set 15 | whithorn
# Processing Record 30 of Set 15 | tete
# Processing Record 31 of Set 15 | ndele
# Processing Record 32 of Set 15 | hashtrud
# Processing Record 33 of Set 15 | venado tuerto
# Processing Record 34 of Set 15 | magistralnyy
# Processing Record 35 of Set 15 | troitsko-pechorsk
# Processing Record 36 of Set 15 | barra do bugres
# Processing Record 37 of Set 15 | pasni
# Processing Record 38 of Set 15 | forli
# Processing Record 39 of Set 15 | klaksvik
# Processing Record 40 of Set 15 | vilyuysk
# Processing Record 41 of Set 15 | nurota
# Processing Record 42 of Set 15 | mount pleasant
# Processing Record 43 of Set 15 | tarauaca
# Processing Record 44 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 45 of Set 15 | panjab
# Processing Record 46 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 47 of Set 15 | yokadouma
# Processing Record 48 of Set 15 | szeged
# Processing Record 49 of Set 15 | gombong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.1500  -70.9167     44.71        76          40
# 1  Puerto Escondido  15.8500  -97.0667     81.43        74           1
# 2            Kodiak  57.7900 -152.4072     26.11        63          90
# 3      Ponta Do Sol  32.6667  -17.1000     63.72        64           3
# 4         Upernavik  72.7868  -56.1549      7.43        65          34
# 5         Jamestown  42.0970  -79.2353     40.59        93          90
# 6           Ushuaia -54.8000  -68.3000     34.05        91           7
# 7             Vaini -21.2000 -175.2000     84.36        79          20
# 8           Dingtao  35.0683  115.5625     55.15        70          86
# 9             Tiksi  71.6872  128.8694    -13.11        97          97
#
#    Wind Speed Country Current Description
# 0       39.12      CL    scattered clouds
# 1        5.75      MX           clear sky
# 2       11.50      US     overcast clouds
# 3        5.30      PT           clear sky
# 4        8.61      GL    scattered clouds
# 5        8.05      US     overcast clouds
# 6        3.89      AR           clear sky
# 7        9.22      TO          few clouds
# 8        9.31      CN          light rain
# 9        6.24      RU     overcast clouds

# %%
#reorder the columns
new_column_order_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"] 
df_new_order = city_data_df[new_column_order_df]
df_new_order
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Punta Arenas      CL -53.1500  -70.9167     44.71        76
# 1    Puerto Escondido      MX  15.8500  -97.0667     81.43        74
# 2              Kodiak      US  57.7900 -152.4072     26.11        63
# 3        Ponta Do Sol      PT  32.6667  -17.1000     63.72        64
# 4           Upernavik      GL  72.7868  -56.1549      7.43        65
# ..                ...     ...      ...       ...       ...       ...
# 690          Tarauaca      BR  -8.1614  -70.7656     72.61        98
# 691            Panjab      AF  34.3880   67.0233     23.49        54
# 692         Yokadouma      CM   3.5167   15.0500     70.27        90
# 693            Szeged      HU  46.2530   20.1482     46.11        85
# 694           Gombong      ID  -7.6072  109.5142     78.87        84
#
#      Cloudiness  Wind Speed Current Description
# 0            40       39.12    scattered clouds
# 1             1        5.75           clear sky
# 2            90       11.50     overcast clouds
# 3             3        5.30           clear sky
# 4            34        8.61    scattered clouds
# ..          ...         ...                 ...
# 690          89        1.77     overcast clouds
# 691           0        2.26           clear sky
# 692          81        1.45       broken clouds
# 693          95        9.53     overcast clouds
# 694         100        0.63     overcast clouds
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
